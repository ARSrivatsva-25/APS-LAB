# %% [markdown]
# <a href="https://colab.research.google.com/github/ARSrivatsva-25/APS-LAB/blob/main/lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    min_tree = {}
    visited = set()
    min_tree[list(graph.keys())[0]] = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        next_vertex = None
        for vertex in min_tree:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited:
                    if weight < min_edge:
                        min_edge = weight
                        next_vertex = adj_vertex

        min_tree[next_vertex] = []
        visited.add(next_vertex)
        min_weight += min_edge

    return min_tree, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Different example of input graph as discussed in lecture slide and use above code to verify the output

# %%
import networkx as nx

# Create a weighted graph
G = nx.Graph()
G.add_edge('A', 'B', weight=4)
G.add_edge('A', 'C', weight=2)
G.add_edge('B', 'C', weight=1)
G.add_edge('B', 'D', weight=5)
G.add_edge('C', 'D', weight=8)

# Minimum Spanning Tree using Prim’s algorithm
mst = nx.minimum_spanning_tree(G, algorithm='prim')

print(sorted(mst.edges(data=True)))

import matplotlib.pyplot as plt

# Create a weighted graph
G = nx.Graph()
G.add_edge('A', 'B', weight=4)
G.add_edge('A', 'C', weight=2)
G.add_edge('B', 'C', weight=1)
G.add_edge('B', 'D', weight=5)
G.add_edge('C', 'D', weight=8)

# Compute MST
mst = nx.minimum_spanning_tree(G, algorithm='prim')

# Draw original graph
pos = nx.spring_layout(G)  # layout for positioning nodes
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=200)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, 'weight'))

plt.title("Original Graph")
plt.show()

# Draw MST
nx.draw(mst, pos, with_labels=True, node_color='lightgreen', node_size=800)
nx.draw_networkx_edge_labels(mst, pos, edge_labels=nx.get_edge_attributes(mst, 'weight'))

plt.title("Minimum Spanning Tree (Prim's Algorithm)")
plt.show()
# Out:
# [('A', 'C', {'weight': 2}), ('B', 'C', {'weight': 1}), ('B', 'D', {'weight': 5})]

# %%
# your sample input of graph
graph2 = {
    "A": {"B": 3, "C": 1},
    "B": {"A": 3, "C": 7, "D": 5},
    "C": {"A": 1, "B": 7, "D": 2, "E": 4},
    "D": {"B": 5, "C": 2, "E": 6},
    "E": {"C": 4, "D": 6}
}

# %%
#run prims algorithm for sample input
mst2, min_weight2 = prim_algorithm(graph2)
print("Minimum Spanning Tree: ", mst2)
print("Minimum Weight: ", min_weight2)
# Out:
# Minimum Spanning Tree:  {'A': [], 'C': [], 'D': [], 'B': [], 'E': []}
# Minimum Weight:  11

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Step 1: Create a weighted graph
G = nx.Graph()
G.add_edge("A", "B", weight=3)
G.add_edge("A", "C", weight=1)
G.add_edge("B", "C", weight=7)
G.add_edge("B", "D", weight=5)
G.add_edge("C", "D", weight=2)
G.add_edge("C", "E", weight=4)
G.add_edge("D", "E", weight=6)

# %%
# implement Kruskal's algorithm
# Using networkx

# Step 2: Compute MST using Kruskal’s algorithm
mst = nx.minimum_spanning_tree(G, algorithm="kruskal")

# Step 3: Print MST edges
print("Minimum Spanning Tree edges (Kruskal):")
print(sorted(mst.edges(data=True)))

# Step 4: Visualize Original Graph
pos = nx.spring_layout(G)  # layout for positioning nodes
nx.draw(G, pos, with_labels=True, node_color="lightblue", node_size=800)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"))
plt.title("Original Graph")
plt.show()

# Step 5: Visualize MST
nx.draw(mst, pos, with_labels=True, node_color="lightgreen", node_size=800)
nx.draw_networkx_edge_labels(mst, pos, edge_labels=nx.get_edge_attributes(mst, "weight"))
plt.title("Minimum Spanning Tree (Kruskal's Algorithm)")
plt.show()
# Out:
# Minimum Spanning Tree edges (Kruskal):
# [('A', 'B', {'weight': 3}), ('A', 'C', {'weight': 1}), ('C', 'D', {'weight': 2}), ('C', 'E', {'weight': 4})]

# %%
# implement Kruskal's algorithm
def kruskal_algorithm(graph):
    parent = {}
    rank = {}

    # Find function (for union-find)
    def find(vertex):
        if parent[vertex] != vertex:
            parent[vertex] = find(parent[vertex])
        return parent[vertex]

    # Union function
    def union(v1, v2):
        root1 = find(v1)
        root2 = find(v2)

        if root1 != root2:
            if rank[root1] > rank[root2]:
                parent[root2] = root1
            elif rank[root1] < rank[root2]:
                parent[root1] = root2
            else:
                parent[root2] = root1
                rank[root1] += 1

    edges = []

    # Convert graph to edge list
    for vertex in graph:
        for adj, weight in graph[vertex].items():
            edges.append((weight, vertex, adj))

    # Sort edges by weight
    edges.sort()

    # Initialize disjoint set
    for vertex in graph:
        parent[vertex] = vertex
        rank[vertex] = 0

    mst = []
    total_weight = 0

    for weight, v1, v2 in edges:
        if find(v1) != find(v2):
            union(v1, v2)
            mst.append((v1, v2, weight))
            total_weight += weight

    return mst, total_weight

# %%
graph = {
    'A': {'B': 2, 'D': 6},
    'B': {'A': 2, 'C': 3, 'D': 8},
    'C': {'B': 3, 'D': 5},
    'D': {'A': 6, 'B': 8, 'C': 5}
}

mst, weight = kruskal_algorithm(graph)

print("Minimum Spanning Tree:", mst)
print("Total Weight:", weight)
# Out:
# Minimum Spanning Tree: [('A', 'B', 2), ('B', 'C', 3), ('C', 'D', 5)]
# Total Weight: 10
