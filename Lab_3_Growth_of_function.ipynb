# %% [markdown]
# <a href="https://colab.research.google.com/github/ARSrivatsva-25/APS-LAB/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt
import time

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

# %%
def sub_two_numbers(a, b):
    return a - b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    sub_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Subtraction")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

# %%
def even_odd_count(numbers):
    even_count = 0
    odd_count = 0
    for value in numbers:
        if value % 2 == 0:
            even_count += value
        odd_count += value
    return even_count, odd_count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.

# %%
import time
import math
import matplotlib.pyplot as plt

def binary_search_iterative(array, x):
    low, high = 0, len(array) - 1
    while low <= high:
        mid = (low + high) // 2
        if array[mid] == x:
            return mid
        elif array[mid] < x:
            low = mid + 1
        else:
            high = mid - 1
    return -1

n_values = list(range(1000, 100001, 5000))
time_values = []

for n in n_values:
    data = list(range(n))
    total_time = 0

    for _ in range(1000):  # repeat to amplify time
        start = time.perf_counter()
        binary_search_iterative(data, n - 1)
        end = time.perf_counter()
        total_time += (end - start)

    time_values.append(total_time / 1000)

# Plot actual time
plt.plot(n_values, time_values, marker='o', label="Actual Time")

# Plot theoretical log n curve
log_n = [math.log2(n) for n in n_values]
scale = time_values[-1] / log_n[-1]
log_n_scaled = [x * scale for x in log_n]

plt.plot(n_values, log_n_scaled, linestyle='--', label="O(log n)")

plt.xlabel("Input size (n)")
plt.ylabel("Time (seconds)")
plt.title("Logarithmic Time Complexity O(log n)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.

# %%
import time
import math
import matplotlib.pyplot as plt


def log_linear_example(data):
    return sorted(data)

n_values = list(range(1000, 50001, 5000))  # larger input sizes
time_values = []

for n in n_values:
    total_time = 0

    for _ in range(5):  # average of 5 runs
        data = list(range(n, 0, -1))  # worst-case input
        start = time.time()
        log_linear_example(data)
        end = time.time()
        total_time += (end - start)

    time_values.append(total_time / 5)


plt.plot(n_values, time_values, marker='o', label="Actual Time")


n_log_n = [n * math.log2(n) for n in n_values]
scale = time_values[-1] / n_log_n[-1]
n_log_n_scaled = [x * scale for x in n_log_n]

plt.plot(n_values, n_log_n_scaled, linestyle='--', label="O(n log n)")

plt.xlabel("Input size (n)")
plt.ylabel("Time (seconds)")
plt.title("Log-Linear Time Complexity O(n log n)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example

# %%
import random

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

n_values = list(range(100, 1100, 100))
time_values = []

# Measure execution time
for n in n_values:
    data = [random.randint(0, n) for _ in range(n)]
    start = time.time()
    bubble_sort(data)
    end = time.time()
    time_values.append(end - start)

plt.figure(figsize=(8,5))
plt.plot(n_values, time_values, marker='o', color='red')
plt.xlabel("Input size n")
plt.ylabel("Time (seconds)")
plt.title("O(n^2) Quadratic Time Complexity - Bubble Sort")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    sorted_left = merge_sort(left_half)
    sorted_right = merge_sort(right_half)
    return merge(sorted_left, sorted_right)
def merge(left, right):
    sorted_result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            sorted_result.append(left[i])
            i += 1
        else:
            sorted_result.append(right[j])
            j += 1
    sorted_result.extend(left[i:])
    sorted_result.extend(right[j:])
    return sorted_result

data = [38, 27, 43, 3, 9, 82, 10]
print(f"Sorted Array: {merge_sort(data)}")

n = np.arange(1, 20)
y_log_linear = n * np.log2(n)    # O(n log n) - Merge Sort
plt.figure
plt.plot(n, y_log_linear)

plt.title("Time Complexity: Log-Linear (Merge Sort)")
plt.xlabel("Values of n", fontsize=12)
plt.ylabel("Time Complexity (Operations)")
plt.show()
# Out:
# Sorted Array: [3, 9, 10, 27, 38, 43, 82]

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure

# %%
#Prob_8 plot graph similar to above figure
import numpy as np
import matplotlib.pyplot as plt


# 1. Define the range for n (Values from 1 to 9 as seen in the graph)
n = np.arange(1, 10)

y_n = n # (f(n) = n)
y_log = np.log2(n) # g(n) = log_2(n)
y_square = n**2 # h(n) = n^2
y_exp = 2**n # k(n) = 2^n

plt.figure
# Plotting each line with specific colors and labels to match the image
plt.plot(n, y_n, label='f(n)=n', color='blue')
plt.plot(n, y_log, label='g(n)=log_2 (n)', color='red')
plt.plot(n, y_square, label='h(n)= n^2', color='green')
plt.plot(n, y_exp, label='k(n)=2^n', color='y') # 'y' is standard yellow

plt.title("Time Complexity Plot")
plt.xlabel("Values of n")
plt.ylabel("Time Complexity")

# Add the legend to the upper left corner
plt.legend(loc='upper left')
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)

# %%
import numpy as np
import matplotlib.pyplot as plt

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[-1]
    left = [x for x in arr[:-1] if x <= pivot]
    right = [x for x in arr[:-1] if x > pivot]
    return quick_sort(left) + [pivot] + quick_sort(right)

# Test Quick Sort output
test_data = [33, 10, 55, 71, 29, 5]
print("Original:", test_data)
print("Sorted:  ", quick_sort(test_data))

# Values of n
n = np.arange(1, 101)
y_log_linear = n * np.log2(n)

# Plot
plt.figure()
plt.plot(n, y_log_linear, label="O(n log n)")
plt.title("Time Complexity: Log-Linear (Quick Sort)")
plt.xlabel("Values of n")
plt.ylabel("Time Complexity (Operations)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Original: [33, 10, 55, 71, 29, 5]
# Sorted:   [5, 10, 29, 33, 55, 71]
